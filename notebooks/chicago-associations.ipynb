# %%
# TODO: move all of this into the ingestion script

# %%
# %pip install -qU openai
# %pip install -qU "psycopg[binary]"
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
sys.path.insert(0, '..')

# %%
# Establish a connection to the muni database

from psycopg import connect

def connection():
    return connect(
        dbname="regrag",
        host="localhost",
        port="5432",
        autocommit=True
    )

# %%
# Go through rows in the muni database and identify definitions

from muni.llm import definition, analyze_context

sql_select = """
    SELECT  id,
        L1_ref, L1_heading,
        L2_ref, L2_heading,
        L3_ref, L3_heading,
        L4_ref, L4_heading,
        text
    FROM muni;
    """

sql_unique = """
    BEGIN
        IF NOT EXISTS (
            SELECT FROM pg_constraint
            WHERE conname = 'unique_associations')
            AND   conrelid = 'muni_associations'::regclass
        ) 
        THEN
            ALTER TABLE muni_associations
            ADD CONSTRAINT unique_associations UNIQUE (jurisdiction, association, left_id, right_id);
        END IF;
    END;
    """

sql_assoc = """
    INSERT INTO muni_associations (jurisdiction, association, left_id, right_id)
    VALUES (%s, %s, %s, %s)
    ON CONFLICT (jurisdiction, association, left_id, right_id) DO NOTHING;
    """

def scope_map(scope):
    """For a given scope, what are the columns in muni that need to match?"""
    table = {'global': ['jurisdiction'],
             'title': ['jurisdiction', 'L1_ref'],
             'chapter': ['jurisdiction', 'L1_ref', 'L2_ref'],
             'article': ['jurisdiction', 'L1_ref', 'L2_ref', 'L3_ref'],
             'section': ['jurisdiction', 'L1_ref', 'L2_ref', 'L3_ref', 'L4_ref']
             }
    if scope not in table.keys():
        return None
    return table[scope]

# %%
def set_defs(conn, id_, scope, association):
    """Set associations with a row in muni with all rows matching the scope.
    Args:
        conn: a connection to the database
        id_: the id of the row to associate
        scope: the scope of the association (e.g. 'title', 'chapter', 'article', 'section')
        association: the type of association (e.g. 'definition')
    """
    with conn.cursor() as cursor:
        # TODO: this should be done as a single query
        # get the jurisdiction and the references
        cursor.execute(f"SELECT jurisdiction, L1_ref, L2_ref, L3_ref, L4_ref FROM muni WHERE id = {id_}")
        jurisdiction, L1_ref, L2_ref, L3_ref, L4_ref = cursor.fetchone()
        # get the columns that need to match
        columns = scope_map(scope)
        if not columns:
            return
        # get the rows that match the scope
        match_str = ' AND '.join([f"{col} = '{val}'" for col, val in zip(columns, [jurisdiction, L1_ref, L2_ref, L3_ref, L4_ref])])
        cursor.execute(f"SELECT id FROM muni WHERE {match_str} AND id != {id_}")
        rows = cursor.fetchall()
        # set the associations
        for row in rows:
            cursor.execute(sql_assoc, (jurisdiction, association, id_, row[0]))

def find_defs(conn):
    with conn.cursor() as cursor:
        cursor.execute(sql_select)
        rows = cursor.fetchall()
        for row in rows:
            id_, L1_ref, L1_heading, L2_ref, L2_heading, L3_ref, L3_heading, L4_ref, L4_heading, text = row
            heading_string = '; '.join([L1_heading, L2_heading, L3_heading, L4_heading])
            # this is simplest, but could extend to more complicated matches for interpretation of language, etc.
            is_definition = 'definition' in heading_string.lower()
            if is_definition:
                headings = {'title': L1_heading, 'chapter': L2_heading, 'article': L3_heading, 'section': L4_heading}
                r = definition(text, headings)
                if r:
                    print("* Setting associations")
                    print(f"  SCOPE: {r}\nHEADINGS: {heading_string}")
                    print("  --> %s ..." % text[:60].replace('\n', ' '))
                    set_defs(conn, id_, r, 'definition')
                    # call to function to set associations                #cursor.execute(sql_insert", (id_, L1, L2, L3, L4, text))

# %%
def set_associations(conn, id_, scope, context_type):
    """Set associations with a row in muni with all rows matching the scope.
    Args:
        conn: a connection to the database
        id_: the id of the row to associate
        scope: the scope of the association (e.g. 'title', 'chapter', 'article', 'section')
        context_type: the type of association (e.g. 'definition')
    """
    with conn.cursor() as cursor:
        # get the jurisdiction and the references
        cursor.execute(f"SELECT jurisdiction, L1_ref, L2_ref, L3_ref, L4_ref FROM muni WHERE id = {id_}")
        jurisdiction, L1_ref, L2_ref, L3_ref, L4_ref = cursor.fetchone()
        # get the columns that need to match
        columns = scope_map(scope)
        if not columns:
            return
        # get the rows that match the scope
        match_str = ' AND '.join([f"{col} = '{val}'" for col, val in zip(columns, [jurisdiction, L1_ref, L2_ref, L3_ref, L4_ref])])
        cursor.execute(f"SELECT id FROM muni WHERE {match_str} AND id != {id_}")
        rows = cursor.fetchall()
        # set the associations
        for row in rows:
            cursor.execute(sql_assoc, (jurisdiction, context_type, id_, row[0]))

def find_associations(conn):
    allowed_types = ['penalty', 'definition', 'interpretation', 'date']
    with conn.cursor() as cursor:
        cursor.execute(sql_select)
        rows = cursor.fetchall()
        for row in rows:
            id_, L1_ref, L1_heading, L2_ref, L2_heading, L3_ref, L3_heading, L4_ref, L4_heading, text = row
            headings = {'title': L1_heading, 'chapter': L2_heading, 'article': L3_heading, 'section': L4_heading}
            r = analyze_context(text, headings, model='gpt-4')
            if r:
                context_type, scope = r
                if context_type in allowed_types:
                    print(f"* Setting associations for id {id_}")
                    print(f"  Context type: {context_type}; Scope: {scope}")
                    print("  --> %s ..." % text[:80].replace('\n', ' '))
                    set_associations(conn, id_, scope, context_type)

# %%
with connection() as conn:
    find_associations(conn)
# Out:
# * Setting associations for id {id_}
#   Context type: date; Scope: global
#   --> This ordinance, consisting of Titles 1 through 18, inclusive, shall be known as  ...
# * Setting associations for id {id_}
#   Context type: date; Scope: global
#   --> The Municipal Code of Chicago shall take effect and be in force from and after i ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: global
#   --> Unless the context requires other interpretations, the following words and terms ...
# * Setting associations for id {id_}
#   Context type: interpretation; Scope: global
#   --> Whenever any words in any section of this Code import the plural number, the sin ...
# * Setting associations for id {id_}
#   Context type: interpretation; Scope: global
#   --> Reference to any section of this Code shall be understood to refer to and includ ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: global
#   --> Whenever in any section of this Code the doing of any act or the omission to do  ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: section
#   --> (a)   Any person who violates any provision of this Code by failing to obtain a  ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: global
#   --> Whenever in this Code a minimum but no maximum fine or penalty is imposed, the c ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: global
#   --> In all cases where the same offense is made punishable or is created by differen ...
# * Setting associations for id {id_}
#   Context type: date; Scope: title
#   --> The comprehensive zoning amendment passed by the city council on March 31, 2004, ...
# * Setting associations for id {id_}
#   Context type: interpretation; Scope: section
#   --> Unless it expressly provides otherwise, no new ordinance that amends or repeals  ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: global
#   --> Each violation of this ordinance shall be punishable by up to 30 days' imprisonm ...
# * Setting associations for id {id_}
#   Context type: interpretation; Scope: global
#   --> Whenever any section of this Code makes reference to the Illinois Complied Statu ...
# * Setting associations for id {id_}
#   Context type: interpretation; Scope: global
#   --> No ordinance that repeals an ordinance repealing a former ordinance, clause or p ...
# * Setting associations for id {id_}
#   Context type: interpretation; Scope: global
#   --> All general provisions, terms, phrases and expressions contained in this Code sh ...
# * Setting associations for id {id_}
#   Context type: interpretation; Scope: global
#   --> If any part, section, sentence, clause or application of this Code shall be adju ...
# /Users/jj/proj/legal-epi/notebooks/../src/muni/llm.py:319: UserWarning: LLM FAILED TO CLASSIFY SCOPE. Response: unclear not in ['title', 'chapter', 'article', 'section']
#   warn(f'LLM FAILED TO CLASSIFY SCOPE. Response: {response} not in {list(headings.keys())}')
# /Users/jj/proj/legal-epi/notebooks/../src/muni/llm.py:319: UserWarning: LLM FAILED TO CLASSIFY SCOPE. Response: Thescopeofthecontext not in ['title', 'chapter', 'article', 'section']
#   warn(f'LLM FAILED TO CLASSIFY SCOPE. Response: {response} not in {list(headings.keys())}')
# * Setting associations for id {id_}
#   Context type: penalty; Scope: article
#   --> ARTICLE I. ALL FOOD ESTABLISHMENTS (7-38-001 et seq.) ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: global
#   --> For the purposes of this ordinance, the following definitions shall apply:     ( ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: chapter
#   --> For purposes of this chapter the following definitions apply:     "Collection co ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: section
#   --> Notwithstanding any other provision of this code to the contrary and in addition ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: section
#   --> Notwithstanding any other provision of this code to the contrary and in addition ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: chapter
#   --> For purposes of this chapter:     The word "costs" includes all costs of the cit ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: chapter
#   --> In any action brought under this chapter, the City of Chicago shall also be enti ...
# * Setting associations for id {id_}
#   Context type: interpretation; Scope: chapter
#   --> Nothing in this chapter shall be construed to impair any cause of action or lega ...
# * Setting associations for id {id_}
#   Context type: interpretation; Scope: chapter
#   --> A provision of this chapter, insofar as it is the same or substantially the same ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: chapter
#   --> Any person who aids, abets, incites, compels or coerces the doing of any act pro ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: chapter
#   --> In addition to any other means authorized by law, the corporation counsel may en ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: chapter
#   --> As used in this chapter:     "Claim" includes any request or demand, whether und ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: article
#   --> As used in this article:     "Action" has the meaning ascribed to the term "city ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: global
#   --> (1)   "Child care facility" means any structure used by a child care provider, s ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: chapter
#   --> (a)   Violation of any section of this chapter or any failure to comply with any ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: chapter
#   --> (a)   The corporation counsel may seek relief with respect to any violation of t ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: chapter
#   --> As used in this chapter, the following are defined and shall be construed as her ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: section
#   --> (a)   Any owner who fails to comply with any of the requirements of Section 7-12 ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: chapter
#   --> Any person who shall violate any of the provisions of this chapter for which no  ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: chapter
#   --> Any person who violates, or who resists the enforcement of, any of the provision ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: article
#   --> "Contagious, epidemic, or communicable disease" means any of the following: chol ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: chapter
#   --> Any person that shall violate any of the provisions of this chapter for which no ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: section
#   --> Upon proof of a violation of Section 7-22-020 or 7-22-030 by any school exempted ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: article
#   --> Article I. Distribution of Drugs and Medicines ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: chapter
#   --> As used in this chapter:     "Cannabis Control Act" means the Cannabis Control A ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: section
#   --> Except as authorized by law, any person who manufactures, with intent to deliver ...
# * Setting associations for id {id_}
#   Context type: interpretation; Scope: chapter
#   --> If any provisions of Sections 7-24-091 through 7-24-097 or the application there ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: chapter
#   --> Any person violating any of the provisions of this chapter for which no other pe ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: article
#   --> Article III. Reserved ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: global
#   --> Article V. Rat Control ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: article
#   --> Article VIII. Bed Bugs ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: article
#   --> ARTICLE I. NUISANCES IN GENERAL (7-28-005 et seq.) ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: chapter
#   --> Except as otherwise provided in this chapter, the following terms shall have the ...
# * Setting associations for id {id_}
#   Context type: interpretation; Scope: global
#   --> In all cases where no provision is herein made defining what are nuisances and h ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: section
#   --> No building, vehicle, structure, receptacle, yard, lot, premises, or part thereo ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: section
#   --> Editor's note – Coun. J. 10-28-97, p. 54730, repealed § 7-28-100, which pertaine ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: chapter
#   --> For the purposes of this chapter the following words and terms shall be understo ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: chapter
#   --> (a)   Standard refuse container. The standard refuse container required by this  ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: section
#   --> Every person owning or operating any business establishment, other than a bed-an ...
# * Setting associations for id {id_}
#   Context type: date; Scope: section
#   --> Editor’s note – Coun. J. 11-20-19, p. 9510, Art. IV, § 21, repealed § 7-28-445,  ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: section
#   --> As used in Sections 7-28-511 through 7-28-519, the following terms and phrases s ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: global
#   --> A.   Any person who violates any provision of this ordinance or its rules and re ...
# * Setting associations for id {id_}
#   Context type: interpretation; Scope: global
#   --> If any provision, clause, sentence, paragraph, section or part of this ordinance ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: chapter
#   --> In addition to other penalties cited in this chapter, if any person or business  ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: section
#   --> It shall be unlawful for any person to have in his possession, or for any person ...
# * Setting associations for id {id_}
#   Context type: interpretation; Scope: section
#   --> If any part, provision, phrase or application of Section 7-28-740 and 7-28-750 i ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: chapter
#   --> (1)   In addition to any other penalty provided by law, and except as otherwise  ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: article
#   --> As used in this article, the following terms are defined as follows:     "Beddin ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: chapter
#   --> (a)   Any operator who violates subsection (a) of Section 7-30-020 of this chapt ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: article
#   --> Any person who violates this article shall be fined not less than $300 nor more  ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: chapter
#   --> For the purposes of this chapter:     (a)   "Commissioner" shall mean the Commis ...
# * Setting associations for id {id_}
#   Context type: interpretation; Scope: chapter
#   --> If any provision, clause, sentence, paragraph, section or part of this chapter o ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: chapter
#   --> For the purposes of this Chapter, the following definitions shall apply:     "Ba ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: chapter
#   --> (a)   A person, corporation, partnership, association or other entity who violat ...
# * Setting associations for id {id_}
#   Context type: interpretation; Scope: chapter
#   --> No reference or omission in this chapter shall be construed to allow smoking if  ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: global
#   --> (a)   For the purpose of this ordinance, a toy is defined as any article that is ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: chapter
#   --> Article VI. Penalty for Violation of Chapter Provisions ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: section
#   --> (a)   The violation of any of the foregoing sections shall be punishable by a fi ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: chapter
#   --> The provisions of this article shall apply to all food establishments, unless ot ...
# /Users/jj/proj/legal-epi/notebooks/../src/muni/llm.py:319: UserWarning: LLM FAILED TO CLASSIFY SCOPE. Response: Thescopeofthiscontext not in ['title', 'chapter', 'article', 'section']
#   warn(f'LLM FAILED TO CLASSIFY SCOPE. Response: {response} not in {list(headings.keys())}')
# * Setting associations for id {id_}
#   Context type: penalty; Scope: chapter
#   --> (a)   Except as otherwise provided in this chapter, the Commissioner of Health s ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: chapter
#   --> The penalty for violations of this chapter is set forth in Section 7-42-090.  (A ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: article
#   --> ARTICLE I. GENERAL PROVISIONS (7-40-005 et seq.) ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: chapter
#   --> The penalty for violations of this chapter is set forth in Section 7-42-090.  (A ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: section
#   --> A $100.00 reinspection fee shall be assessed against the licensee of any establi ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: chapter
#   --> Any person who shall violate any of the provisions of this chapter shall be fine ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: chapter
#   --> (a)   If any person violates, or resists the enforcement of, this chapter, Chapt ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: global
#   --> Except as otherwise provided in this Code, any person who violates, or who resis ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: chapter
#   --> For purposes of this chapter:     "Extermination by fumigation" means the use of ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: chapter
#   --> For the purposes of this chapter, when any of the following words or terms are u ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: global
#   --> (1)   Definitions. The following definitions are applicable strictly in the cont ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: chapter
#   --> When any of the following words or terms are used in this chapter, whether or no ...
# * Setting associations for id {id_}
#   Context type: interpretation; Scope: chapter
#   --> If any provision of this chapter, or the application of any provision of this ch ...
# * Setting associations for id {id_}
#   Context type: interpretation; Scope: section
#   --> This section shall be known and may by cited as the "Hotel AED Ordinance", and s ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: global
#   --> As used in this Act:     "Automated external defibrillator" means a medical devi ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: chapter
#   --> As used in this chapter, unless the context otherwise requires:     "Electric ut ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: chapter
#   --> (a)   Any electric utility company that violates this chapter or any rules promu ...
# * Setting associations for id {id_}
#   Context type: interpretation; Scope: global
#   --> Nothing in this ordinance shall be construed to preclude or interfere with the i ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: chapter
#   --> As used in this chapter, unless the context otherwise requires:     "Executive D ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: chapter
#   --> (a)   Any gas utility company that violates this chapter or any rules promulgate ...
# * Setting associations for id {id_}
#   Context type: interpretation; Scope: chapter
#   --> Nothing in this chapter shall be construed to preclude or interfere with the imp ...
# /Users/jj/proj/legal-epi/notebooks/../src/muni/llm.py:254: UserWarning: LLM FAILED TO CLASSIFY CONTEXT. Response: Thistextblockincludesboth not in ['rule', 'penalty', 'definition', 'interpretation', 'date', 'other']
#   warn(f'LLM FAILED TO CLASSIFY CONTEXT. Response: {response} not in {list(CONTEXT_TYPES.keys())}')
# * Setting associations for id {id_}
#   Context type: definition; Scope: section
#   --> (a)   For the purposes of this section, the following definitions shall apply:   ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: section
#   --> Whoever, without reasonable cause, does any one or more of the following:        ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: section
#   --> (a)   Definition. For purposes of this section, "public transportation safety zo ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: section
#   --> (a)   Definitions. For purposes of this section, the following definitions apply ...
# /Users/jj/proj/legal-epi/notebooks/../src/muni/llm.py:254: UserWarning: LLM FAILED TO CLASSIFY CONTEXT. Response: Thistextblockcontainsboth not in ['rule', 'penalty', 'definition', 'interpretation', 'date', 'other']
#   warn(f'LLM FAILED TO CLASSIFY CONTEXT. Response: {response} not in {list(CONTEXT_TYPES.keys())}')
# * Setting associations for id {id_}
#   Context type: penalty; Scope: chapter
#   --> Any person violating any of the provisions of this chapter, where no other penal ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: section
#   --> The license of any such person or employees thereof directly involved in the vio ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: section
#   --> A.   For the purposes of this section the following words shall be defined as fo ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: section
#   --> Any person violating any of the provisions of Section 8-8-110 shall be deemed gu ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: chapter
#   --> Any person violating any of the provisions of this chapter, where no other penal ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: chapter
#   --> Any person violating any provision of this chapter, where no other penalty is sp ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: chapter
#   --> As used in this chapter:     "Cannabis" has the meaning ascribed to that term in ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: chapter
#   --> Any person who shall violate any of the provisions of this chapter for which no  ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: article
#   --> Article II. Possession of Firearms ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: chapter
#   --> For purposes of this chapter the following terms shall apply:     "The Act" mean ...
# * Setting associations for id {id_}
#   Context type: interpretation; Scope: chapter
#   --> If any provision or term of this chapter, or any application thereof, is held in ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: chapter
#   --> (a)   Unless the enhanced penalty imposed by subsection 8-4-350(b)(2) or subsect ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: chapter
#   --> For the purposes of this Chapter, the following definitions apply:     "Ballisti ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: chapter
#   --> Any person violating any of the provisions of this chapter, where no other penal ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: chapter
#   --> For purposes of this chapter, the following definitions apply:     "Conviction"  ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: chapter
#   --> Any person who violates any provision of this chapter, or rule or regulation pro ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: chapter
#   --> Whenever used in this chapter, the following words and phrases shall have the fo ...
# * Setting associations for id {id_}
#   Context type: definition; Scope: chapter
#   --> When used in this chapter, the following terms have the stated definitions:      ...
# * Setting associations for id {id_}
#   Context type: interpretation; Scope: chapter
#   --> In case of a conflict between any sections of this chapter, the provision which  ...
# * Setting associations for id {id_}
#   Context type: penalty; Scope: chapter
#   --> (a)   Unless otherwise specifically provided, a violation of this chapter is sub ...

# %%
# Create associations between definitions and the rows in the muni database

# %%
# Pull out definitions along with their associated rows
